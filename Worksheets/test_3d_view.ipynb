# %%
version()
# Out:
# 'SageMath version 8.9.rc0, Release Date: 2019-09-11'

# %%
g = sphere()
g
# Out:
# Graphics3d Object

# %%
show(g, viewer='threejs')
# Out:
# Graphics3d Object

# %%
show(g, viewer='tachyon')
# Out:
# Graphics3d Object
